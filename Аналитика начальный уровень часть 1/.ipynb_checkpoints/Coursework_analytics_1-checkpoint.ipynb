# %% [markdown]
# # Курсовая работа. Блок 1
# *Pandas и Matplotlib*
#
# **NB!** Код должен быть с комментариями к каждому логическому блоку кода. В противном случае работа **не** будет принята. <br><br>
# Выполнение курсовой работы может потребовать использование дополнительных библиотек.
#
# <br><br>
# **Описание работы:**
#
# Перед вами стоит бизнес-задача – на основании имеющихся данных подготовить аналитический отчет, который в дальнейшем поможет продюсерам образовательных программ эффективно выстраивать стратегию по модернизированию и улучшению курсов. В начале отчета предлагается оформить емкий описательный блок по каждому курсу на основании рассчитанных показателей. Далее предлагается посчитать потенциальную нагрузку на преподавателей, чтобы оценить необходимость расширения штата сотрудников. Затем идет блок из двух пунктов по анализу качества контента курсов, где необходимо выявить проблемные модули, которые, возможно, требуют доработки. Также стоит задача выявить потенциальную сезонность. Наконец, предложено задание для самостоятельной разработки метрики успеваемости студентов для нахождения тех, кто значительно хуже справляются с прохождением курса. Каждый из пунктов анализа предполагается сопроводить аналитическим выводом на основании рассчитанных метрик.
#
# <br><br>
#
# _________
# Обозначения:<br><br>
# &nbsp;&nbsp;&nbsp;&nbsp;**(p)** – задание может быть выполнено после прохождения модулей по Pandas <br>
# &nbsp;&nbsp;&nbsp;&nbsp;**(m)** – задание может быть выполнено после прохождения модуля по Matplotlib <br>
# &nbsp;&nbsp;&nbsp;&nbsp;⭐ – необязательное задание повышенной сложности
# _________
#
# [Codebook](#Codebook) <br>
# [1. Описание и начальная работа с данными](#1.1-Описание-и-начальная-работа-с-данными)<br>
# [2. Расчет потенциальной нагрузки на преподавателей](#2.-Расчет-потенциальной-нагрузки-на-преподавателей)<br>
# [3. Выявление проблемных модулей](#3.-Выявление-проблемных-модулей)<br>
# [4. Расчет конверсии](#4.-Расчет-конверсии) <br>
# [5. Метрика успеваемости ](#5.-Метрика-успеваемости)

# %% [markdown]
# ## Codebook
#
# `courses.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `id` – идентификатор курса <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `title` – название курса <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `field` – сфера, к которой относится курс <br> <br><br>
# `students.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `id` – идентификатор студента <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `city` – город студента <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `birthday` – день рождения студента <br> <br><br>
# `course_contents.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `course_id` – идентификатор курса <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `module_number` – номер модуля <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `module_title` – название модуля <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `lesson_number` – номер урока <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `lesson_title` – название урока <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `lesson_token` – токен урока <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `is_video` – наличие видео *(true/false)* <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `is_homework` – наличие домашней работы *(true/false)* <br>
# <br><br>
# `progresses.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `id` – идентификатор прогресса <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `student_id` – идентификатор студента <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `course_id` – идентификатор курса <br> <br><br>
# `progress_phases.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `progress_id` – идентификатор прогресса <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `module_number` – номер модуля <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `lesson_number` – номер урока <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `status` – статус прохождения урока <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `start_date` – дата начала <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `finish_date` – дата окончания <br>
# <br><br>

# %% [markdown]
# ## 1. Описание и начальная работа с данными
#
# Вам необходимо подготовить данные и описать их. Данные реальные и содержат пропущенные значения, а также лишние относительно друг друга данные. <br>
#
# Объедините датасеты (кроме `students.scv`) в один общий для дальнейшей работы. Отдельный датасет создайте для расчета среднего возраста студентов курсов (отдельный датасет со `students.scv` нужен, чтобы в основном не потерять значения в основном датасете из-за того, что не по всем студентам есть анкетные данные о дате рождения). <br> <br>
# Опишите данные: <br>
# 1. **(p)** Посчитайте
#       * общее количество курсов в датасете,
#       * количество модулей на каждом курсе,
#       * количество уроков в каждом модуле на каждом курсе,
#       * медианное количество уроков в модуле на каждом курсе,
#       * количество учеников на каждом курсе
#       * минимальный, максимальный, средний, медианный возраст студентов
#       * минимальный, максимальный, средний, медианный возраст студентов на каждом курсе
# 2. **(m)** Постройте bar-chart, отражающий количество студентов на каждом курсе. Ticks нужно развернуть так, чтобы они были читаемы
# 3. **(m)** Постройте горизонтальный (столбцы должны располагаться горизонтально) bar-chart, отражающий количество студентов на каждом курсе. График должен иметь заголовок. Значения должны быть отсортированы. Цвет столбцов должен содержать информацию о сфере, к которой относится курс (то есть нужна легенда). Прозрачность должна стоять на отметке 0.1. На график должна быть нанесена линия медианы. У медианы должен быть свой цвет. Рамки у графика быть не должно ⭐
# 4.     На основании рассчитанных значений опишите данные (описание должно быть полным и покрывать все полученные выше метрики)
#
# _____________________________________________________________________

# %% [markdown]
# Для того, чтобы проверить, что вы правильно соединили все датасеты в основной (без `students.csv`), запустите аналогичный приведенному ниже запрос. Выдача должна совпадать. Имейте в виду, что названия некоторых столбцов были переименованы.

# %%
main[main.student_id == '768c2987a744c51ce64a5993a2a94eaf'] # проверка основного датасета
# Out:
#                              progress_id  module_number  lesson_number status  \
# 0       a387ab916f402cb3fbfffd29f68fd0ce              2              4   done
# 1       a387ab916f402cb3fbfffd29f68fd0ce              1              1   done
# 2       a387ab916f402cb3fbfffd29f68fd0ce              2              2   done
# 3       a387ab916f402cb3fbfffd29f68fd0ce              1              4   done
# 4       a387ab916f402cb3fbfffd29f68fd0ce              1              6   done
# 5       a387ab916f402cb3fbfffd29f68fd0ce              2              1   done
# 6       a387ab916f402cb3fbfffd29f68fd0ce              1              3   done
# 7       a387ab916f402cb3fbfffd29f68fd0ce              2              5  start
# 8       a387ab916f402cb3fbfffd29f68fd0ce              1              2   done
# 9       a387ab916f402cb3fbfffd29f68fd0ce              1              5   done
# 10      a387ab916f402cb3fbfffd29f68fd0ce              2              3   done
# 112420  6407c290505e790e92207a1dbc41a2cd              1              1  start
# 132870  5767046d89ed7563a0c3a9a3896a23e6              1              3   done
# 132871  5767046d89ed7563a0c3a9a3896a23e6              2              2   done
# 132872  5767046d89ed7563a0c3a9a3896a23e6              1              1   done
# 132873  5767046d89ed7563a0c3a9a3896a23e6              1              2   done
# 132874  5767046d89ed7563a0c3a9a3896a23e6              2              1   done
# 132875  5767046d89ed7563a0c3a9a3896a23e6              2              3   fail
# 155020  c90ebe1431eac5cbb11692100b7a0f8d              1              3   done
# 155021  c90ebe1431eac5cbb11692100b7a0f8d              1              1   done
# 155022  c90ebe1431eac5cbb11692100b7a0f8d              1              7  start
# 155023  c90ebe1431eac5cbb11692100b7a0f8d              1              5   done
# 155024  c90ebe1431eac5cbb11692100b7a0f8d              1              6   done
# 155025  c90ebe1431eac5cbb11692100b7a0f8d              1              4   done
# 155026  c90ebe1431eac5cbb11692100b7a0f8d              1              2   done
#
#                            start_date                    finish_date  \
# 0       2018-06-23 08:28:50.681065+00  2018-06-23 08:28:52.439542+00
# 1       2018-06-20 14:25:21.783762+00  2018-06-20 15:45:07.717209+00
# 2       2018-06-23 08:18:09.653771+00  2018-06-23 08:18:12.784616+00
# 3        2018-06-20 16:00:06.36178+00  2018-06-21 19:09:30.845034+00
# 4       2018-06-21 19:10:36.957891+00  2018-06-28 15:59:25.320418+00
# 5       2018-06-23 08:18:07.476199+00  2018-06-23 08:18:09.552181+00
# 6       2018-06-20 15:58:22.132468+00  2018-06-20 16:00:06.127191+00
# 7       2018-06-23 08:31:00.338883+00                            NaN
# 8       2018-06-20 15:45:07.976223+00  2018-06-20 15:58:21.886722+00
# 9       2018-06-21 19:09:31.117521+00  2018-06-21 19:10:36.707919+00
# 10      2018-06-23 08:18:12.890698+00  2018-06-23 08:28:50.564437+00
# 112420  2018-06-20 14:25:13.010259+00                            NaN
# 132870  2018-02-19 12:32:35.928905+00  2018-02-20 09:16:36.741375+00
# 132871  2018-02-22 08:57:31.008346+00  2018-04-28 13:45:40.708228+00
# 132872         2018-01-13 15:20:23+00         2018-01-13 15:20:23+00
# 132873         2018-01-13 15:20:23+00         2018-01-14 13:47:25+00
# 132874  2018-02-22 08:54:10.987784+00  2018-02-22 08:57:30.914939+00
# 132875  2018-04-28 13:45:40.955076+00                            NaN
# 155020  2018-06-19 15:08:14.103923+00  2018-06-19 15:39:53.661163+00
# 155021  2018-06-19 10:40:05.063485+00  2018-06-19 14:56:16.346353+00
# 155022  2018-06-19 18:40:00.576904+00                            NaN
# 155023  2018-06-19 18:10:52.316728+00  2018-06-19 18:35:38.720317+00
# 155024  2018-06-19 18:35:38.884217+00  2018-06-19 18:37:11.155066+00
# 155025  2018-06-19 15:39:53.923777+00    2018-06-19 18:10:52.1737+00
# 155026  2018-06-19 14:56:16.570129+00  2018-06-19 15:08:13.930725+00
#
#                               student_id                         course_id  \
# 0       768c2987a744c51ce64a5993a2a94eaf  c9fcb746d51e41bc5a217002d081454b
# 1       768c2987a744c51ce64a5993a2a94eaf  c9fcb746d51e41bc5a217002d081454b
# 2       768c2987a744c51ce64a5993a2a94eaf  c9fcb746d51e41bc5a217002d081454b
# 3       768c2987a744c51ce64a5993a2a94eaf  c9fcb746d51e41bc5a217002d081454b
# 4       768c2987a744c51ce64a5993a2a94eaf  c9fcb746d51e41bc5a217002d081454b
# 5       768c2987a744c51ce64a5993a2a94eaf  c9fcb746d51e41bc5a217002d081454b
# 6       768c2987a744c51ce64a5993a2a94eaf  c9fcb746d51e41bc5a217002d081454b
# 7       768c2987a744c51ce64a5993a2a94eaf  c9fcb746d51e41bc5a217002d081454b
# 8       768c2987a744c51ce64a5993a2a94eaf  c9fcb746d51e41bc5a217002d081454b
# 9       768c2987a744c51ce64a5993a2a94eaf  c9fcb746d51e41bc5a217002d081454b
# 10      768c2987a744c51ce64a5993a2a94eaf  c9fcb746d51e41bc5a217002d081454b
# 112420  768c2987a744c51ce64a5993a2a94eaf  dad6f6ffc086caa89e2f40c28a9c7490
# 132870  768c2987a744c51ce64a5993a2a94eaf  04ba6d0b40670c43a209141fa01fa784
# 132871  768c2987a744c51ce64a5993a2a94eaf  04ba6d0b40670c43a209141fa01fa784
# 132872  768c2987a744c51ce64a5993a2a94eaf  04ba6d0b40670c43a209141fa01fa784
# 132873  768c2987a744c51ce64a5993a2a94eaf  04ba6d0b40670c43a209141fa01fa784
# 132874  768c2987a744c51ce64a5993a2a94eaf  04ba6d0b40670c43a209141fa01fa784
# 132875  768c2987a744c51ce64a5993a2a94eaf  04ba6d0b40670c43a209141fa01fa784
# 155020  768c2987a744c51ce64a5993a2a94eaf  e9bb9205eeed307ee7cbaa08bfd166c3
# 155021  768c2987a744c51ce64a5993a2a94eaf  e9bb9205eeed307ee7cbaa08bfd166c3
# 155022  768c2987a744c51ce64a5993a2a94eaf  e9bb9205eeed307ee7cbaa08bfd166c3
# 155023  768c2987a744c51ce64a5993a2a94eaf  e9bb9205eeed307ee7cbaa08bfd166c3
# 155024  768c2987a744c51ce64a5993a2a94eaf  e9bb9205eeed307ee7cbaa08bfd166c3
# 155025  768c2987a744c51ce64a5993a2a94eaf  e9bb9205eeed307ee7cbaa08bfd166c3
# 155026  768c2987a744c51ce64a5993a2a94eaf  e9bb9205eeed307ee7cbaa08bfd166c3
#
#                 course_title course_field  \
# 0         Веб-дизайн PRO 2.0       Design
# 1         Веб-дизайн PRO 2.0       Design
# 2         Веб-дизайн PRO 2.0       Design
# 3         Веб-дизайн PRO 2.0       Design
# 4         Веб-дизайн PRO 2.0       Design
# 5         Веб-дизайн PRO 2.0       Design
# 6         Веб-дизайн PRO 2.0       Design
# 7         Веб-дизайн PRO 2.0       Design
# 8         Веб-дизайн PRO 2.0       Design
# 9         Веб-дизайн PRO 2.0       Design
# 10        Веб-дизайн PRO 2.0       Design
# 112420             UX-дизайн       Design
# 132870  Анимация интерфейсов       Design
# 132871  Анимация интерфейсов       Design
# 132872  Анимация интерфейсов       Design
# 132873  Анимация интерфейсов       Design
# 132874  Анимация интерфейсов       Design
# 132875  Анимация интерфейсов       Design
# 155020     JavaScript с нуля  Development
# 155021     JavaScript с нуля  Development
# 155022     JavaScript с нуля  Development
# 155023     JavaScript с нуля  Development
# 155024     JavaScript с нуля  Development
# 155025     JavaScript с нуля  Development
# 155026     JavaScript с нуля  Development
#
#                                              module_title  \
# 0                                   Концептуальный дизайн
# 1                 Специализация и личное позиционирование
# 2                                   Концептуальный дизайн
# 3                 Специализация и личное позиционирование
# 4                 Специализация и личное позиционирование
# 5                                   Концептуальный дизайн
# 6                 Специализация и личное позиционирование
# 7                                   Концептуальный дизайн
# 8                 Специализация и личное позиционирование
# 9                 Специализация и личное позиционирование
# 10                                  Концептуальный дизайн
# 112420       Профессия дизайнера в эпоху цифровых перемен
# 132870  Введение в Motion Design. Тренды, разновидност...
# 132871        12 принципов анимации от Walt Disney Studio
# 132872  Введение в Motion Design. Тренды, разновидност...
# 132873  Введение в Motion Design. Тренды, разновидност...
# 132874        12 принципов анимации от Walt Disney Studio
# 132875        12 принципов анимации от Walt Disney Studio
# 155020                                Знакомство с языком
# 155021                                Знакомство с языком
# 155022                                Знакомство с языком
# 155023                                Знакомство с языком
# 155024                                Знакомство с языком
# 155025                                Знакомство с языком
# 155026                                Знакомство с языком
#
#                                              lesson_title  \
# 0                                       Практика — мокапы
# 1                                             Интро курса
# 2                         Что такое концептуальный дизайн
# 3                                 Личное позиционирование
# 4                                         Домашняя работа
# 5                                    Брифинг от заказчика
# 6                                     Домашнее задание #1
# 7                                         Домашняя работа
# 8                                           Специализация
# 9                                     Домашнее задание #2
# 10                            Практика — дизайн-концепция
# 112420                                        Приветствие
# 132870                                    Домашняя работа
# 132871                              12 принципов анимации
# 132872                                         Знакомство
# 132873  Введение в Motion Design. Тренды, разновидност...
# 132874                                              Интро
# 132875                                    Домашняя работа
# 155020                           Инструменты разработчика
# 155021                                              Интро
# 155022                                    Домашняя работа
# 155023                                    Синтаксис языка
# 155024                                              Аутро
# 155025                                      Hello, world!
# 155026    Что умеет JavaScript и почему он так популярен?
#
#                                 lesson_token  is_video  is_homework
# 0       7df8adef-1259-4b72-9bf2-353c73389d06      True        False
# 1       df1a1f20-cdf7-443d-b25b-0a4b990b84d9      True        False
# 2       f23b1890-9365-406f-816b-04864cefe58f      True        False
# 3       9dd50916-4aa6-4a73-b86c-56a1bd7753c8      True        False
# 4       43e1fbdd-1ee9-4ed5-a577-4dadd80c02b3     False         True
# 5       a25caa09-95d0-4e0c-b3c0-ad15f23bead8      True        False
# 6       a3d74174-08be-4634-949a-108d4f915fa6      True        False
# 7       90c5f618-e9f3-4af8-96ab-f41b312bfa77     False         True
# 8       558acc64-3867-4ada-ac6f-36e9a7922f68      True        False
# 9       7ea421f0-04b5-4df8-a76c-03e24692eba9      True        False
# 10      beb5abe6-b101-4003-a5ed-a87add92210a      True        False
# 112420  86d0d49c-5590-4c0b-8fca-927191bb3fd5      True        False
# 132870  c4377574-d117-45c7-8da5-dd7d1923517d     False         True
# 132871  7eea2930-11db-45c9-a16c-0d800b6dc99d      True        False
# 132872  aa344de3-1191-4e69-b485-61823118f71c      True        False
# 132873  246c8429-dd18-4f3a-a9fb-d3c07e7d6912      True        False
# 132874  7ea16a2d-e6d1-4158-907f-ae0ce8379c45      True        False
# 132875  f6f37ada-7763-4a06-9e45-a42ca568e69a     False         True
# 155020  460c54ea-d899-44d3-8940-00302ff5f2e5      True        False
# 155021  0d4678b0-abfe-4132-9193-97f9b0f08d3a      True        False
# 155022  af6e818e-08f0-4e32-981e-95a35395ee8f     False         True
# 155023  fe10ef7f-44cb-4184-b06f-d7c38b0e81a5      True        False
# 155024  efe6a65b-a9a2-4d3a-910a-750e72c3f118      True        False
# 155025  73315f69-8587-4f46-ab6b-fe57c8f1aa52      True        False
# 155026  6af5b93a-593b-48a0-bb03-42fa2571ede5      True        False

# %%
# 1. Загрузим из файлов и объединим датасеты (все кроме students.scv) в один общий
# - датасеты progresses и progress_phases объединим по идентификатору прогресса в общий датасет
# - к общему датасету добавим courses и course_contents со связью по идентификатору курса, номер модуля, номер урока  
import pandas as pd

df_courses = pd.read_csv("./Data/courses.csv", encoding="UTF-8")
df_course_contents = pd.read_csv("./Data/course_contents.csv", encoding="UTF-8")
df_progresses = pd.read_csv("./Data/progresses.csv", encoding="UTF-8")
df_progress_phases = pd.read_csv("./Data/progress_phases.csv", encoding="UTF-8")

result = pd.merge(df_progress_phases, df_progresses, how='left', left_on='progress_id', right_on='id')
result2 = pd.merge(result, df_courses, how='left', left_on=['course_id'], right_on=['id'])
main = pd.merge(result2, df_course_contents, how='left', 
                   left_on=['course_id', 'module_number', 'lesson_number'], 
                   right_on=['course_id', 'module_number', 'lesson_number'])
del main['id_y']
del main['id_x']
del main['Unnamed: 0']

# %%
main[main.student_id == '768c2987a744c51ce64a5993a2a94eaf'] # проверка основного датасета
# Out:
#                              progress_id  module_number  lesson_number status  \
# 0       a387ab916f402cb3fbfffd29f68fd0ce              2              4   done
# 1       a387ab916f402cb3fbfffd29f68fd0ce              1              1   done
# 2       a387ab916f402cb3fbfffd29f68fd0ce              2              2   done
# 3       a387ab916f402cb3fbfffd29f68fd0ce              1              4   done
# 4       a387ab916f402cb3fbfffd29f68fd0ce              1              6   done
# 5       a387ab916f402cb3fbfffd29f68fd0ce              2              1   done
# 6       a387ab916f402cb3fbfffd29f68fd0ce              1              3   done
# 7       a387ab916f402cb3fbfffd29f68fd0ce              2              5  start
# 8       a387ab916f402cb3fbfffd29f68fd0ce              1              2   done
# 9       a387ab916f402cb3fbfffd29f68fd0ce              1              5   done
# 10      a387ab916f402cb3fbfffd29f68fd0ce              2              3   done
# 112420  6407c290505e790e92207a1dbc41a2cd              1              1  start
# 132870  5767046d89ed7563a0c3a9a3896a23e6              1              3   done
# 132871  5767046d89ed7563a0c3a9a3896a23e6              2              2   done
# 132872  5767046d89ed7563a0c3a9a3896a23e6              1              1   done
# 132873  5767046d89ed7563a0c3a9a3896a23e6              1              2   done
# 132874  5767046d89ed7563a0c3a9a3896a23e6              2              1   done
# 132875  5767046d89ed7563a0c3a9a3896a23e6              2              3   fail
# 155020  c90ebe1431eac5cbb11692100b7a0f8d              1              3   done
# 155021  c90ebe1431eac5cbb11692100b7a0f8d              1              1   done
# 155022  c90ebe1431eac5cbb11692100b7a0f8d              1              7  start
# 155023  c90ebe1431eac5cbb11692100b7a0f8d              1              5   done
# 155024  c90ebe1431eac5cbb11692100b7a0f8d              1              6   done
# 155025  c90ebe1431eac5cbb11692100b7a0f8d              1              4   done
# 155026  c90ebe1431eac5cbb11692100b7a0f8d              1              2   done
#
#                            start_date                    finish_date  \
# 0       2018-06-23 08:28:50.681065+00  2018-06-23 08:28:52.439542+00
# 1       2018-06-20 14:25:21.783762+00  2018-06-20 15:45:07.717209+00
# 2       2018-06-23 08:18:09.653771+00  2018-06-23 08:18:12.784616+00
# 3        2018-06-20 16:00:06.36178+00  2018-06-21 19:09:30.845034+00
# 4       2018-06-21 19:10:36.957891+00  2018-06-28 15:59:25.320418+00
# 5       2018-06-23 08:18:07.476199+00  2018-06-23 08:18:09.552181+00
# 6       2018-06-20 15:58:22.132468+00  2018-06-20 16:00:06.127191+00
# 7       2018-06-23 08:31:00.338883+00                            NaN
# 8       2018-06-20 15:45:07.976223+00  2018-06-20 15:58:21.886722+00
# 9       2018-06-21 19:09:31.117521+00  2018-06-21 19:10:36.707919+00
# 10      2018-06-23 08:18:12.890698+00  2018-06-23 08:28:50.564437+00
# 112420  2018-06-20 14:25:13.010259+00                            NaN
# 132870  2018-02-19 12:32:35.928905+00  2018-02-20 09:16:36.741375+00
# 132871  2018-02-22 08:57:31.008346+00  2018-04-28 13:45:40.708228+00
# 132872         2018-01-13 15:20:23+00         2018-01-13 15:20:23+00
# 132873         2018-01-13 15:20:23+00         2018-01-14 13:47:25+00
# 132874  2018-02-22 08:54:10.987784+00  2018-02-22 08:57:30.914939+00
# 132875  2018-04-28 13:45:40.955076+00                            NaN
# 155020  2018-06-19 15:08:14.103923+00  2018-06-19 15:39:53.661163+00
# 155021  2018-06-19 10:40:05.063485+00  2018-06-19 14:56:16.346353+00
# 155022  2018-06-19 18:40:00.576904+00                            NaN
# 155023  2018-06-19 18:10:52.316728+00  2018-06-19 18:35:38.720317+00
# 155024  2018-06-19 18:35:38.884217+00  2018-06-19 18:37:11.155066+00
# 155025  2018-06-19 15:39:53.923777+00    2018-06-19 18:10:52.1737+00
# 155026  2018-06-19 14:56:16.570129+00  2018-06-19 15:08:13.930725+00
#
#                               student_id                         course_id  \
# 0       768c2987a744c51ce64a5993a2a94eaf  c9fcb746d51e41bc5a217002d081454b
# 1       768c2987a744c51ce64a5993a2a94eaf  c9fcb746d51e41bc5a217002d081454b
# 2       768c2987a744c51ce64a5993a2a94eaf  c9fcb746d51e41bc5a217002d081454b
# 3       768c2987a744c51ce64a5993a2a94eaf  c9fcb746d51e41bc5a217002d081454b
# 4       768c2987a744c51ce64a5993a2a94eaf  c9fcb746d51e41bc5a217002d081454b
# 5       768c2987a744c51ce64a5993a2a94eaf  c9fcb746d51e41bc5a217002d081454b
# 6       768c2987a744c51ce64a5993a2a94eaf  c9fcb746d51e41bc5a217002d081454b
# 7       768c2987a744c51ce64a5993a2a94eaf  c9fcb746d51e41bc5a217002d081454b
# 8       768c2987a744c51ce64a5993a2a94eaf  c9fcb746d51e41bc5a217002d081454b
# 9       768c2987a744c51ce64a5993a2a94eaf  c9fcb746d51e41bc5a217002d081454b
# 10      768c2987a744c51ce64a5993a2a94eaf  c9fcb746d51e41bc5a217002d081454b
# 112420  768c2987a744c51ce64a5993a2a94eaf  dad6f6ffc086caa89e2f40c28a9c7490
# 132870  768c2987a744c51ce64a5993a2a94eaf  04ba6d0b40670c43a209141fa01fa784
# 132871  768c2987a744c51ce64a5993a2a94eaf  04ba6d0b40670c43a209141fa01fa784
# 132872  768c2987a744c51ce64a5993a2a94eaf  04ba6d0b40670c43a209141fa01fa784
# 132873  768c2987a744c51ce64a5993a2a94eaf  04ba6d0b40670c43a209141fa01fa784
# 132874  768c2987a744c51ce64a5993a2a94eaf  04ba6d0b40670c43a209141fa01fa784
# 132875  768c2987a744c51ce64a5993a2a94eaf  04ba6d0b40670c43a209141fa01fa784
# 155020  768c2987a744c51ce64a5993a2a94eaf  e9bb9205eeed307ee7cbaa08bfd166c3
# 155021  768c2987a744c51ce64a5993a2a94eaf  e9bb9205eeed307ee7cbaa08bfd166c3
# 155022  768c2987a744c51ce64a5993a2a94eaf  e9bb9205eeed307ee7cbaa08bfd166c3
# 155023  768c2987a744c51ce64a5993a2a94eaf  e9bb9205eeed307ee7cbaa08bfd166c3
# 155024  768c2987a744c51ce64a5993a2a94eaf  e9bb9205eeed307ee7cbaa08bfd166c3
# 155025  768c2987a744c51ce64a5993a2a94eaf  e9bb9205eeed307ee7cbaa08bfd166c3
# 155026  768c2987a744c51ce64a5993a2a94eaf  e9bb9205eeed307ee7cbaa08bfd166c3
#
#                        title        field  \
# 0         Веб-дизайн PRO 2.0       Design
# 1         Веб-дизайн PRO 2.0       Design
# 2         Веб-дизайн PRO 2.0       Design
# 3         Веб-дизайн PRO 2.0       Design
# 4         Веб-дизайн PRO 2.0       Design
# 5         Веб-дизайн PRO 2.0       Design
# 6         Веб-дизайн PRO 2.0       Design
# 7         Веб-дизайн PRO 2.0       Design
# 8         Веб-дизайн PRO 2.0       Design
# 9         Веб-дизайн PRO 2.0       Design
# 10        Веб-дизайн PRO 2.0       Design
# 112420             UX-дизайн       Design
# 132870  Анимация интерфейсов       Design
# 132871  Анимация интерфейсов       Design
# 132872  Анимация интерфейсов       Design
# 132873  Анимация интерфейсов       Design
# 132874  Анимация интерфейсов       Design
# 132875  Анимация интерфейсов       Design
# 155020     JavaScript с нуля  Development
# 155021     JavaScript с нуля  Development
# 155022     JavaScript с нуля  Development
# 155023     JavaScript с нуля  Development
# 155024     JavaScript с нуля  Development
# 155025     JavaScript с нуля  Development
# 155026     JavaScript с нуля  Development
#
#                                              module_title  \
# 0                                   Концептуальный дизайн
# 1                 Специализация и личное позиционирование
# 2                                   Концептуальный дизайн
# 3                 Специализация и личное позиционирование
# 4                 Специализация и личное позиционирование
# 5                                   Концептуальный дизайн
# 6                 Специализация и личное позиционирование
# 7                                   Концептуальный дизайн
# 8                 Специализация и личное позиционирование
# 9                 Специализация и личное позиционирование
# 10                                  Концептуальный дизайн
# 112420       Профессия дизайнера в эпоху цифровых перемен
# 132870  Введение в Motion Design. Тренды, разновидност...
# 132871        12 принципов анимации от Walt Disney Studio
# 132872  Введение в Motion Design. Тренды, разновидност...
# 132873  Введение в Motion Design. Тренды, разновидност...
# 132874        12 принципов анимации от Walt Disney Studio
# 132875        12 принципов анимации от Walt Disney Studio
# 155020                                Знакомство с языком
# 155021                                Знакомство с языком
# 155022                                Знакомство с языком
# 155023                                Знакомство с языком
# 155024                                Знакомство с языком
# 155025                                Знакомство с языком
# 155026                                Знакомство с языком
#
#                                              lesson_title  \
# 0                                       Практика — мокапы
# 1                                             Интро курса
# 2                         Что такое концептуальный дизайн
# 3                                 Личное позиционирование
# 4                                         Домашняя работа
# 5                                    Брифинг от заказчика
# 6                                     Домашнее задание #1
# 7                                         Домашняя работа
# 8                                           Специализация
# 9                                     Домашнее задание #2
# 10                            Практика — дизайн-концепция
# 112420                                        Приветствие
# 132870                                    Домашняя работа
# 132871                              12 принципов анимации
# 132872                                         Знакомство
# 132873  Введение в Motion Design. Тренды, разновидност...
# 132874                                              Интро
# 132875                                    Домашняя работа
# 155020                           Инструменты разработчика
# 155021                                              Интро
# 155022                                    Домашняя работа
# 155023                                    Синтаксис языка
# 155024                                              Аутро
# 155025                                      Hello, world!
# 155026    Что умеет JavaScript и почему он так популярен?
#
#                                 lesson_token  is_video  is_homework
# 0       7df8adef-1259-4b72-9bf2-353c73389d06      True        False
# 1       df1a1f20-cdf7-443d-b25b-0a4b990b84d9      True        False
# 2       f23b1890-9365-406f-816b-04864cefe58f      True        False
# 3       9dd50916-4aa6-4a73-b86c-56a1bd7753c8      True        False
# 4       43e1fbdd-1ee9-4ed5-a577-4dadd80c02b3     False         True
# 5       a25caa09-95d0-4e0c-b3c0-ad15f23bead8      True        False
# 6       a3d74174-08be-4634-949a-108d4f915fa6      True        False
# 7       90c5f618-e9f3-4af8-96ab-f41b312bfa77     False         True
# 8       558acc64-3867-4ada-ac6f-36e9a7922f68      True        False
# 9       7ea421f0-04b5-4df8-a76c-03e24692eba9      True        False
# 10      beb5abe6-b101-4003-a5ed-a87add92210a      True        False
# 112420  86d0d49c-5590-4c0b-8fca-927191bb3fd5      True        False
# 132870  c4377574-d117-45c7-8da5-dd7d1923517d     False         True
# 132871  7eea2930-11db-45c9-a16c-0d800b6dc99d      True        False
# 132872  aa344de3-1191-4e69-b485-61823118f71c      True        False
# 132873  246c8429-dd18-4f3a-a9fb-d3c07e7d6912      True        False
# 132874  7ea16a2d-e6d1-4158-907f-ae0ce8379c45      True        False
# 132875  f6f37ada-7763-4a06-9e45-a42ca568e69a     False         True
# 155020  460c54ea-d899-44d3-8940-00302ff5f2e5      True        False
# 155021  0d4678b0-abfe-4132-9193-97f9b0f08d3a      True        False
# 155022  af6e818e-08f0-4e32-981e-95a35395ee8f     False         True
# 155023  fe10ef7f-44cb-4184-b06f-d7c38b0e81a5      True        False
# 155024  efe6a65b-a9a2-4d3a-910a-750e72c3f118      True        False
# 155025  73315f69-8587-4f46-ab6b-fe57c8f1aa52      True        False
# 155026  6af5b93a-593b-48a0-bb03-42fa2571ede5      True        False

# %%
# 1.1 посчитаю общее количество курсов в датасете
# у каждого курса есть "id" по нему и буду считать. 
# Для этого мне понадобиться колонка "course_id" из общего датасета

df = pd.DataFrame( main.groupby('course_id'))
number_of_courses = df.shape[0]
print(f"общее количество курсов в датасете = {number_of_courses}")
# Out:
# общее количество курсов в датасете = 15

# %%
# 1.2 количество модулей на каждом курсе
# Для этого мне понадобяться колонки 'title', 'module_title' из датасета

df = main.loc[:, ['title', 'module_title']]  
df1 = df.groupby(['title', 'module_title']).count()
df1['module_title_sum'] = 1
mts = df1.groupby('title').count()
for i in main.loc[:, ['title', 'module_title']].groupby('title').groups:
    print(f"На курсе {i} количество модулей = {mts.loc[i, 'module_title_sum']}")
# Out:
# На курсе Excel Базовый количество модулей = 9
# На курсе Java-разработчик количество модулей = 17
# На курсе Java-разработчик c нуля количество модулей = 9
# На курсе JavaScript с нуля количество модулей = 18
# На курсе PHP-разработчик с 0 до PRO. Часть 1 количество модулей = 8
# На курсе SMM-маркетолог от А до Я количество модулей = 11
# На курсе UX-дизайн количество модулей = 20
# На курсе Анимация интерфейсов количество модулей = 21
# На курсе Веб-вёрстка для начинающих 2.0 количество модулей = 8
# На курсе Веб-дизайн PRO 2.0 количество модулей = 17
# На курсе Веб-дизайн Базовый количество модулей = 17
# На курсе Веб-дизайн с нуля 2.0 количество модулей = 19
# На курсе Веб-разработчик количество модулей = 20
# На курсе Интернет-маркетолог от Ingate количество модулей = 18
# На курсе Руководитель digital-проектов количество модулей = 17

# %%
# либо же в виде таблицы - количество модулей на каждом курсе
mts
# Out:
#                                      module_title_sum
# title
# Excel Базовый                                       9
# Java-разработчик                                   17
# Java-разработчик c нуля                             9
# JavaScript с нуля                                  18
# PHP-разработчик с 0 до PRO. Часть 1                 8
# SMM-маркетолог от А до Я                           11
# UX-дизайн                                          20
# Анимация интерфейсов                               21
# Веб-вёрстка для начинающих 2.0                      8
# Веб-дизайн PRO 2.0                                 17
# Веб-дизайн Базовый                                 17
# Веб-дизайн с нуля 2.0                              19
# Веб-разработчик                                    20
# Интернет-маркетолог от Ingate                      18
# Руководитель digital-проектов                      17

# %%
# 1.3 количество уроков в каждом модуле на каждом курсе

df = main.loc[:, ['title', 'module_title', 'lesson_title']]
df1 = df.groupby(['title', 'module_title', 'lesson_title']).count()
df1['lesson_title_sum'] = 1
mts = df1.groupby(['title', 'module_title']).count()
# выведем таблицу показывающую количество уроков в каждом модуле на каждом курсе
mts
# Out:
#                                                                                   lesson_title_sum
# title                         module_title
# Excel Базовый                  Визуализация данных Excel                                         5
#                               Основной функционал Excel                                         11
#                               Основной функционал Excel (продолжение)                            7
#                               Сводные таблицы Excel                                              5
#                               Формулы и функции Excel. Более сложные формулы                     5
# ...                                                                                            ...
# Руководитель digital-проектов Решение факапов. Lean/TOC. Обзор.                                  5
#                               Требовательность digital-продюсера                                 4
#                               Управление временем                                                4
#                               Управление дизайнерами. Разработка дизайна по s...                 7
#                               Экологичный путь менеджера                                         4
#
# [229 rows x 1 columns]

# %%
# 1.4 медианное количество уроков в модуле на каждом курсе

mts.groupby(['title']).agg('median')
# Out:
#                                      lesson_title_sum
# title
# Excel Базовый                                     5.0
# Java-разработчик                                  7.0
# Java-разработчик c нуля                          10.0
# JavaScript с нуля                                 7.0
# PHP-разработчик с 0 до PRO. Часть 1               4.0
# SMM-маркетолог от А до Я                          6.0
# UX-дизайн                                         3.5
# Анимация интерфейсов                              3.0
# Веб-вёрстка для начинающих 2.0                    7.0
# Веб-дизайн PRO 2.0                                5.0
# Веб-дизайн Базовый                                3.0
# Веб-дизайн с нуля 2.0                             4.0
# Веб-разработчик                                   2.0
# Интернет-маркетолог от Ingate                     6.5
# Руководитель digital-проектов                     5.0

# %%
# 1.5 количество учеников на каждом курсе
# у каждого студента есть идентификатор, а потому нам нужна колонка "student_id"

# создадим датафрейм с колонками 'title' и 'student_id' из основного датасета
df_student_id = main.loc[:, ['title', 'student_id']] 

# сгруппируем колонки в полученном датафрейме
df_si = df_student_id.groupby(['title', 'student_id']).count()

# добавим новую колонку для числового подсчета студентов
df_si['student_id_sum'] = 1

# Найдем количество студентов по курсам
df_number_students_course = df_si.groupby('title').count()

# выводим таблицу с результатом
df_number_students_course
# Out:
#                                      student_id_sum
# title
# Excel Базовый                                   782
# Java-разработчик                                763
# Java-разработчик c нуля                         581
# JavaScript с нуля                               966
# PHP-разработчик с 0 до PRO. Часть 1             854
# SMM-маркетолог от А до Я                        506
# UX-дизайн                                      1151
# Анимация интерфейсов                            598
# Веб-вёрстка для начинающих 2.0                 2004
# Веб-дизайн PRO 2.0                             1711
# Веб-дизайн Базовый                              518
# Веб-дизайн с нуля 2.0                          2014
# Веб-разработчик                                 628
# Интернет-маркетолог от Ingate                  2168
# Руководитель digital-проектов                   685

# %%
from datetime import datetime
import pandas as pd

# получим данные по студентам
df_students = pd.read_csv("./Data/students.csv", encoding="UTF-8")

# создам новый датафрейм с идентификаторами студентов и их датами рождения
ds = df_students.loc[:, ['id', 'birthday']]

# студенты без возраста нам не нужны, удалим их
ds = ds.dropna()

# вычислим возраст студентов по их дате рождения и добавим в новую колонку 'age'
f = lambda x: int(datetime.today().year) - int(str(x[:x.find('-')]))
ds['age'] = ds.loc[:, 'birthday'].apply(f)

# ДОРАБОТКА по замечанию
# так же удалю, студентов указавших не верные данные по возрасту, а именно не вошедшие в возраст, больше 18 
# и меньше 90, думаю это правильно.
ds = ds[(ds['age'] >= 18) & (ds['age'] <= 90)]

# выведим возраст в порядке возрастания
ds.sort_values('age')
# Out:
#                                      id    birthday  age
# 20212  16468253cbf3f591524577530e38e885  2002-10-04   18
# 24298  c6954b3a031fba88dcfcb14dee637141  2002-09-26   18
# 18754  45b1fb4c788db946a0c9861ead26a65b  2002-02-21   18
# 12031  37d58ddcbf57b718994a416aaf37bd95  2002-09-29   18
# 20329  9ad9d07a855c49427d7c911fee3fd74d  2002-05-07   18
# ...                                 ...         ...  ...
# 38352  c0dc087e0701bfb688e8d1f28bad024d  1935-03-08   85
# 36150  e927618e1f5be8179bddda81aaabfe42  1931-01-01   89
# 3575   9389179a11a2d7dd62064d0beb1df8e8  1930-04-01   90
# 10816  d436744d921b382db0050ef873c3da24  1930-01-12   90
# 32372  3b8702007c213dabb0d857337775ab36  1930-01-01   90
#
# [24711 rows x 3 columns]

# %%
# 1.6 минимальный, максимальный, средний, медианный возраст студентов
print(f"минимальный возраст студентов = {ds['age'].min()}")
print(f"максимальный возраст студентов = {ds['age'].max()}") 
print(f"средний возраст студентов = {ds['age'].mean()}")  
print(f"медианный возраст студентов = {ds['age'].median()}")
# Out:
# минимальный возраст студентов = 18
# максимальный возраст студентов = 90
# средний возраст студентов = 30.05131318036502
# медианный возраст студентов = 29.0

# %%
# 1.7 минимальный, максимальный, средний, медианный возраст студентов на каждом курсе
# переменную - df_student_id мы получали ранее

# получу таблицу с колонками id и age
df_id_age = ds.loc[:, ['id', 'age']]

# соединим таблицы df_student_id и df_id_age, по колонкам student_id и id
df = pd.merge(df_student_id, df_id_age, left_on=['student_id'], right_on=['id'])

# %%
# выведим возраста по курсам
df.groupby('title').agg(['min', 'max', 'mean', 'median'])
# Out:
#                                     age
#                                     min max       mean median
# title
# Excel Базовый                        18  61  33.691598     34
# Java-разработчик                     18  65  30.464808     29
# Java-разработчик c нуля              18  55  30.861952     30
# JavaScript с нуля                    18  60  29.198380     28
# PHP-разработчик с 0 до PRO. Часть 1  18  75  31.610096     30
# SMM-маркетолог от А до Я             18  52  29.326734     29
# UX-дизайн                            18  85  30.867521     30
# Анимация интерфейсов                 18  51  30.422707     30
# Веб-вёрстка для начинающих 2.0       18  60  29.333649     28
# Веб-дизайн PRO 2.0                   18  59  29.142191     28
# Веб-дизайн Базовый                   18  51  29.155472     28
# Веб-дизайн с нуля 2.0                18  76  28.725518     28
# Веб-разработчик                      18  51  28.231156     27
# Интернет-маркетолог от Ingate        18  60  31.831337     31
# Руководитель digital-проектов        19  55  32.349246     32

# %% [markdown]
# 2. **(m)** Постройте bar-chart, отражающий количество студентов на каждом курсе. Ticks нужно развернуть так, чтобы они были читаемы

# %%
# 2. Постройте bar-chart, отражающий количество студентов на каждом курсе. 
# Ticks нужно развернуть так, чтобы они были читаемы

import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters

# %matplotlib inline

register_matplotlib_converters()
fig, subplot = plt.subplots()

# получаем данные по графику
air_df = df_number_students_course.loc[:, 'student_id_sum']
x_axis = df_number_students_course.index.values

subplot.bar(x = x_axis, height = air_df.values)

# подписи для оси Ох
x_labels = [str(i) for i in air_df.index.values]

# добавляем подписи к осям
plt.xticks(air_df.index.values, rotation='vertical', labels=x_labels)

plt.show()

# %% [markdown]
# 4.     На основании рассчитанных значений опишите данные (описание должно быть полным и покрывать все полученные выше метрики)

# %% [markdown]
# **Вывод** Смотря на полученные данные можно сказать что самыми популярными курсами являются "Веб-дизайн с нуля 2.0", "Интернет-маркетолог от Ingate", "Веб-вёрстка для начинающих 2.0", возраст учеников в среднем порядка 29 лет.

# %% [markdown]
# ## 2. Расчет потенциальной нагрузки на преподавателей
#
# 1. **(p)** Рассчитать прирост студентов на каждом курсе в каждом месяце за всю историю (каждый месяц в диапазоне от марта 2016 до июля 2019 включительно). Считать дату начала прохождения курса студентом по дате начала первой домашней работы.
# 2. **(m)** На основании первого пункта построить line-graph с приростом студентов в каждом месяце для каждого курса. 15 графиков. Графики должны иметь заголовки, оси должны быть подписаны. Ticks нужно развернуть так, чтобы они были читаемы.
# 3. **(m)** На основании первого пункта построить line-graph с несколькими линиями, отражающими прирост студентов в каждом месяце для каждого курса. 15 линий на графике. Ticks нужно развернуть так, чтобы они были читаемы. График должен иметь заголовок. Ось, отражающая прирост, должна быть подписана. Линия для каждого курса должна иметь свой цвет (нужна легенда). Рамок у графика быть не должно ⭐
# 4. **(p)** Рассчитать количество прогрессов по выполнению домашних работ в каждом месяце за всю историю (каждый месяц в диапазоне от марта 2016 до июля 2019 включительно) для каждого курса. Учитывать, что выполнение домашнего задания может перетекать из одного месяца в другой (такие дз надо включать в общее число прогрессов для всех месяцев, которые покрывает срок выполнения этих дз)
# 5. **(m)** Построить line-graph по четвертому пункту. 15 графиков. Графики должны иметь заголовки, оси должны быть подписаны. Ticks нужно развернуть так, чтобы они были читаемы
# 6. **(m)** Построить один line-graph для всех курсов по четвертому пункту. 15 линий на графике. Ticks нужно развернуть так, чтобы они были читаемы. График должен иметь заголовок. Ось, отражающая количество прогрессов, должна быть подписана. Линия для каждого курса должна иметь свой цвет (нужна легенда). Рамок у графика быть не должно ⭐
# 7. На основании рассчитанных значений сделайте аналитический вывод (должен быть полным и покрывать все полученные выше метрики)

# %%
# Подготовка данных
import pandas as pd

df_courses = pd.read_csv("./Data/courses.csv", encoding="UTF-8")
df_course_contents = pd.read_csv("./Data/course_contents.csv", encoding="UTF-8")
df_progresses = pd.read_csv("./Data/progresses.csv", encoding="UTF-8")
df_progress_phases = pd.read_csv("./Data/progress_phases.csv", encoding="UTF-8")

result = pd.merge(df_progress_phases, df_progresses, how='left', left_on='progress_id', right_on='id')
result2 = pd.merge(result, df_courses, how='left', left_on=['course_id'], right_on=['id'])
main = pd.merge(result2, df_course_contents, how='left', 
                   left_on=['course_id', 'module_number', 'lesson_number'], 
                   right_on=['course_id', 'module_number', 'lesson_number'])
del main['id_y']
del main['id_x']
del main['Unnamed: 0']
main.head()
# Out:
#                         progress_id  module_number  lesson_number status  \
# 0  a387ab916f402cb3fbfffd29f68fd0ce              2              4   done
# 1  a387ab916f402cb3fbfffd29f68fd0ce              1              1   done
# 2  a387ab916f402cb3fbfffd29f68fd0ce              2              2   done
# 3  a387ab916f402cb3fbfffd29f68fd0ce              1              4   done
# 4  a387ab916f402cb3fbfffd29f68fd0ce              1              6   done
#
#                       start_date                    finish_date  \
# 0  2018-06-23 08:28:50.681065+00  2018-06-23 08:28:52.439542+00
# 1  2018-06-20 14:25:21.783762+00  2018-06-20 15:45:07.717209+00
# 2  2018-06-23 08:18:09.653771+00  2018-06-23 08:18:12.784616+00
# 3   2018-06-20 16:00:06.36178+00  2018-06-21 19:09:30.845034+00
# 4  2018-06-21 19:10:36.957891+00  2018-06-28 15:59:25.320418+00
#
#                          student_id                         course_id  \
# 0  768c2987a744c51ce64a5993a2a94eaf  c9fcb746d51e41bc5a217002d081454b
# 1  768c2987a744c51ce64a5993a2a94eaf  c9fcb746d51e41bc5a217002d081454b
# 2  768c2987a744c51ce64a5993a2a94eaf  c9fcb746d51e41bc5a217002d081454b
# 3  768c2987a744c51ce64a5993a2a94eaf  c9fcb746d51e41bc5a217002d081454b
# 4  768c2987a744c51ce64a5993a2a94eaf  c9fcb746d51e41bc5a217002d081454b
#
#                 title   field                             module_title  \
# 0  Веб-дизайн PRO 2.0  Design                    Концептуальный дизайн
# 1  Веб-дизайн PRO 2.0  Design  Специализация и личное позиционирование
# 2  Веб-дизайн PRO 2.0  Design                    Концептуальный дизайн
# 3  Веб-дизайн PRO 2.0  Design  Специализация и личное позиционирование
# 4  Веб-дизайн PRO 2.0  Design  Специализация и личное позиционирование
#
#                       lesson_title                          lesson_token  \
# 0                Практика — мокапы  7df8adef-1259-4b72-9bf2-353c73389d06
# 1                      Интро курса  df1a1f20-cdf7-443d-b25b-0a4b990b84d9
# 2  Что такое концептуальный дизайн  f23b1890-9365-406f-816b-04864cefe58f
# 3          Личное позиционирование  9dd50916-4aa6-4a73-b86c-56a1bd7753c8
# 4                  Домашняя работа  43e1fbdd-1ee9-4ed5-a577-4dadd80c02b3
#
#    is_video  is_homework
# 0      True        False
# 1      True        False
# 2      True        False
# 3      True        False
# 4     False         True

# %%
from datetime import datetime
f = lambda x: datetime.strptime(str(x[:x.find(' ')]),"%Y-%m-%d").strftime("%Y%m")

# %%
### YOUR CODE HERE ### ДОРАБОТАННО
# Рассчитать прирост студентов на каждом курсе в каждом месяце за всю историю 
# (каждый месяц в диапазоне от марта 2016 до июля 2019 включительно). 
# Считать дату начала прохождения курса студентом по дате начала первой домашней работы.

# выберем нужные столбцы
df = main.loc[:, ['title', 'student_id', 'start_date', 'is_homework']]

# так как считать дату начала прохождения курса студентом по дате начала первой домашней работы , то
# выбираю данные с домашней работой
df = df[df['is_homework'] == True]

# Добавлю новую колонку с годом и месяцем из start_date
# f = lambda x: datetime.strptime(str(x[:x.find(' ')]),"%Y-%m-%d").strftime("%Y%m")
df['year_month'] = df.loc[:, 'start_date'].apply(f)

# найду месяца с началом первых домашних работ
df_group_students = df.loc[:, ['title', 'year_month', 'student_id']].groupby(
    ['title', 'student_id']).agg(
    {'year_month':'min'}).sort_values(['title','year_month']).reset_index()

# найду количество студентов по месяцам
df_count_students = df_group_students.groupby(['title', 'year_month']).agg('count').reset_index()

# переименую колонку
df_count_students.rename(columns={'student_id': 'student_count'}, inplace=True)

# найду месяца по курсам
df_background = df.loc[:, ['title', 'year_month', 'student_id']].groupby(
    ['title','year_month']).agg('count').sort_values(['title',
                                            'year_month']).reset_index()

# свяжу две таблицы, заполню пустые значения  
df_gr = pd.merge(df_background.loc[:, ['title', 'year_month']], df_count_students, how='outer', 
                   left_on=['title', 'year_month'],
                   right_on=['title', 'year_month']).fillna(0)

# изменю тип колонки на тип int
df_gr['student_count'] = df_gr['student_count'].astype('int')
df_gr
# Out:
#                              title year_month  student_count
# 0                    Excel Базовый     201802              6
# 1                    Excel Базовый     201803              3
# 2                    Excel Базовый     201804              0
# 3                    Excel Базовый     201805              3
# 4                    Excel Базовый     201806              9
# 5                    Excel Базовый     201807             13
# 6                    Excel Базовый     201808             15
# 7                    Excel Базовый     201809             40
# 8                    Excel Базовый     201810             30
# 9                    Excel Базовый     201811             33
# 10                   Excel Базовый     201812             43
# 11                   Excel Базовый     201901             52
# 12                   Excel Базовый     201902             46
# 13                   Excel Базовый     201903             63
# 14                   Excel Базовый     201904             46
# 15                   Excel Базовый     201905             45
# 16                   Excel Базовый     201906             43
# 17                   Excel Базовый     201907             28
# 18                Java-разработчик     201801              1
# 19                Java-разработчик     201802             14
# 20                Java-разработчик     201803             26
# 21                Java-разработчик     201804             14
# 22                Java-разработчик     201805             25
# 23                Java-разработчик     201806             33
# 24                Java-разработчик     201807             48
# 25                Java-разработчик     201808             29
# 26                Java-разработчик     201809             53
# 27                Java-разработчик     201810             33
# 28                Java-разработчик     201811             32
# 29                Java-разработчик     201812            102
# ..                             ...        ...            ...
# 221  Интернет-маркетолог от Ingate     201810             96
# 222  Интернет-маркетолог от Ingate     201811             72
# 223  Интернет-маркетолог от Ingate     201812            106
# 224  Интернет-маркетолог от Ingate     201901            146
# 225  Интернет-маркетолог от Ingate     201902            124
# 226  Интернет-маркетолог от Ingate     201903            125
# 227  Интернет-маркетолог от Ingate     201904            115
# 228  Интернет-маркетолог от Ingate     201905            140
# 229  Интернет-маркетолог от Ingate     201906            114
# 230  Интернет-маркетолог от Ingate     201907             91
# 231  Руководитель digital-проектов     201705              1
# 232  Руководитель digital-проектов     201706              1
# 233  Руководитель digital-проектов     201802             66
# 234  Руководитель digital-проектов     201803             42
# 235  Руководитель digital-проектов     201804             32
# 236  Руководитель digital-проектов     201805             27
# 237  Руководитель digital-проектов     201806             36
# 238  Руководитель digital-проектов     201807             30
# 239  Руководитель digital-проектов     201808             30
# 240  Руководитель digital-проектов     201809             35
# 241  Руководитель digital-проектов     201810             27
# 242  Руководитель digital-проектов     201811             30
# 243  Руководитель digital-проектов     201812             38
# 244  Руководитель digital-проектов     201901             63
# 245  Руководитель digital-проектов     201902             29
# 246  Руководитель digital-проектов     201903             36
# 247  Руководитель digital-проектов     201904             17
# 248  Руководитель digital-проектов     201905             25
# 249  Руководитель digital-проектов     201906             15
# 250  Руководитель digital-проектов     201907             20
#
# [251 rows x 3 columns]

# %% [markdown]
# 2. **(m)** На основании первого пункта построить line-graph с приростом студентов в каждом месяце для каждого курса. 15 графиков. Графики должны иметь заголовки, оси должны быть подписаны. Ticks нужно развернуть так, чтобы они были читаемы.

# %%
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters

# %matplotlib inline

# получаем данные по графику
df_gr.index = df_gr.title
df_title = df_courses.groupby(['title']).count().reset_index()

# %%
# выведу графики
for i in df_title.loc[:, 'title'].values:
    
    register_matplotlib_converters()
    fig, subplot = plt.subplots()
    
    x = list(j[0] for j in df_gr.loc[i, 'year_month': 'student_count'].values)
    y = list(j[1] for j in df_gr.loc[i, 'year_month': 'student_count'].values)
    
    # график функции
    subplot.plot(x, y)

    # подписываем график
    subplot.set_title(str(i))
    
    # станавливаем название для оси  OX
    subplot.set_ylabel('Количество студентов')

    # подписи для оси Ох
    x_labels = [str(i) for i in x]

    # добавляем подписи к осям
    plt.xticks(x, rotation='vertical', labels=x_labels)

    plt.show()

# %% [markdown]
# 4. **(p)** Рассчитать количество прогрессов по выполнению домашних работ в каждом месяце за всю историю (каждый месяц в диапазоне от марта 2016 до июля 2019 включительно) для каждого курса. Учитывать, что выполнение домашнего задания может перетекать из одного месяца в другой (такие дз надо включать в общее число прогрессов для всех месяцев, которые покрывает срок выполнения этих дз)

# %%
# выберем нужные столбцы
df = main.loc[:, ['title', 'start_date', 'finish_date', 'progress_id', 'is_homework']]

# так как считать дату начала прохождения курса студентом по дате начала первой домашней работы , то
# выбираю данные с домашней работой
df = df[df['is_homework'] == True]

# %%
# не заполненые прогрессы нам не нужны, так как по ним нет нагрузки на преподавателя
df = df.dropna()

# %%
from datetime import datetime
f = lambda x: datetime.strptime(str(x[:x.find(' ')]),"%Y-%m-%d").strftime("%Y%m")

# %%
# Добавлю новую колонку с годом и месяцем из start_date
df['start_year_month'] = df.loc[:, 'start_date'].apply(f)
df['finish_year_month'] = df.loc[:, 'finish_date'].apply(f)

# %%
# создам новый датафрейм с нужными данными
df_finish = df.loc[:, ['title',
                       'progress_id',
                       'start_year_month' ,
                       'finish_year_month']].groupby(['title', 'finish_year_month', 'progress_id']).count().reset_index()

# %%
# Рассчитать количество прогрессов по выполнению домашних работ в каждом месяце за всю историю для каждого курса 
df_gr = df_finish.loc[:, [
    'title',
    'progress_id',
    'finish_year_month']
].groupby(['title', 'finish_year_month']).agg('count').sort_values(['title',
                                            'finish_year_month']).reset_index()

# %%
df_gr[df_gr.title == 'Excel Базовый']
# Out:
#             title finish_year_month  progress_id
# 0   Excel Базовый            201802            6
# 1   Excel Базовый            201803            3
# 2   Excel Базовый            201804            3
# 3   Excel Базовый            201805            4
# 4   Excel Базовый            201806            9
# 5   Excel Базовый            201807           21
# 6   Excel Базовый            201808           23
# 7   Excel Базовый            201809           51
# 8   Excel Базовый            201810           68
# 9   Excel Базовый            201811           72
# 10  Excel Базовый            201812           83
# 11  Excel Базовый            201901           88
# 12  Excel Базовый            201902           99
# 13  Excel Базовый            201903          105
# 14  Excel Базовый            201904           93
# 15  Excel Базовый            201905           98
# 16  Excel Базовый            201906           81
# 17  Excel Базовый            201907           69

# %% [markdown]
# 5. **(m)** Построить line-graph по четвертому пункту. 15 графиков. Графики должны иметь заголовки, оси должны быть подписаны.
# Ticks нужно развернуть так, чтобы они были читаемы

# %%
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters

# %matplotlib inline

# получаем данные по графику
df_gr.index = df_gr.title
df_title = df_courses.groupby(['title']).count().reset_index()

# %%
# выведу графики
for i in df_title.loc[:, 'title'].values:
    
    register_matplotlib_converters()
    fig, subplot = plt.subplots()
    
    x = list(j[0] for j in df_gr.loc[i, 'finish_year_month': 'progress_id'].values)
    y = list(j[1] for j in df_gr.loc[i, 'finish_year_month': 'progress_id'].values)
    
    # график функции
    subplot.plot(x, y)

    # подписываем график
    subplot.set_title(str(i))
    
    # станавливаем название для оси  OX
    subplot.set_ylabel('Количество прогрессов')

    # подписи для оси Ох
    x_labels = [str(i) for i in x]

    # добавляем подписи к осям
    plt.xticks(x, rotation='vertical', labels=x_labels)

    plt.show()

# %% [markdown]
# 7. На основании рассчитанных значений сделайте аналитический вывод (должен быть полным и покрывать все полученные выше метрики)

# %% [markdown]
# **Вывод** На основании рассчитанных значений, в полной мере и с уверенностью могу сказать что по притоку студентов практически на всех графиках наблюдается первоначальный рост и быстрый спад студентов после 2019 года (куда все убегаю, может я тоже туда пойду ?), так же и по загруженности учителей где в большинстве курсов наблюдается рост и последующий спад по нагрузке с начала 2019 года.

# %% [markdown]
# ## 3. Выявление проблемных модулей
#
# 1. **(p)** Рассчитать минимальное, максимальное, среднее, медианное время прохождения каждого модуля (разность между временем начала и окончания выполнения домашней работы) для каждого курса. Если домашних заданий в модуле несколько, то считать разность между временем начала выполнения первой домашней работы и временем окончания выполнения последней домашней работы в модуле
# 2. **(m)** На основании первого пункта построить line-graph с медианным временем прохождения каждого модуля для каждого курса. 15 графиков. Графики должны иметь заголовки
# 3. **(p)**  Чтобы выявить сезонность, посчитать медианное время выполнения домашней работы по месяцам (12 месяцев, январь-декабрь) для каждого курса.
# 4. **(m)** На основании третьего пункта построить line-graph, на который будут нанесены линии для каждого курса с медианным временем выполнения домашней работы по месяцам. 15 линий на графике. График должен иметь заголовок. Ось, отражающая время прохождения, должна быть подписана. Линия для каждого курса должна иметь свой цвет (нужна легенда). Рамок у графика быть не должно  ⭐
# 5. На основании рассчитанных значений сделайте аналитический вывод (должен быть полным и покрывать все полученные выше метрики)

# %% [markdown]
# 1. **(p)** Рассчитать минимальное, максимальное, среднее, медианное время прохождения каждого модуля (разность между временем начала и окончания выполнения домашней работы) для каждого курса. Если домашних заданий в модуле несколько, то считать разность между временем начала выполнения первой домашней работы и временем окончания выполнения последней домашней работы в модуле

# %%
# Подготовка
from datetime import datetime, MAXYEAR

# %%
# выберем нужные столбцы
df = main.loc[:, ['course_id', 
                  'title', 
                  'student_id', 
                  'start_date', 
                  'finish_date', 
                  'module_title', 
                  'is_homework']].sort_values('start_date', axis = 0)

# выбираю данные с домашней работой
df = df[df['is_homework'] == True]

# %%
# преобразую к типу дата колонки 'start_date' и 'finish_date'
df['start_date'] = pd.to_datetime(df['start_date'])
df['finish_date'] = pd.to_datetime(df['finish_date'])
df.dtypes
# Out:
# course_id                    object
# title                        object
# student_id                   object
# start_date      datetime64[ns, UTC]
# finish_date     datetime64[ns, UTC]
# module_title                 object
# is_homework                    bool
# dtype: object

# %%
# Возьму нужные колонки
df_res = df.loc[:, ['title', 'module_title', 'student_id', 'start_date', 'finish_date']]

# %%
# Найду время прохождения каждого модуля исходя из условия - Если домашних заданий в модуле несколько, то считать 
# разность между временем начала выполнения первой домашней работы и временем окончания выполнения последней домашней
# работы в модуле
df_finish_max = df_res.loc[:, ['title', 'module_title', 'student_id', 'finish_date']].groupby(
    ['title', 'module_title', 'student_id',]).max()

# %%
df_start_min = df_res.loc[:, ['title', 'module_title', 'student_id', 'start_date']].groupby(
    ['title', 'module_title', 'student_id',]).min()

# %%
Series_result = df_finish_max.finish_date - df_start_min.start_date

# %%
df_result = pd.DataFrame(Series_result, columns=['difference_date']).reset_index()

# %%
# функция возвращает секунды из данных типа "timedelta"
def days_seconds(td):
    return td.seconds

# %%
# для удобного расчета переведу колонку 'difference_date' в секунды
df_result['difference_date'] = df_result.loc[:, 'difference_date'].apply(days_seconds)

# %%
# Найду 'min', 'max', 'mean', 'median' по времени каждого модуля для каждого курса
df_result.loc[:, ['title', 'module_title', 'difference_date']].groupby(
    ['title', 'module_title']).agg(['min', 'max', 'mean', 'median'])
# Out:
#                                                                                  difference_date  \
#                                                                                              min
# title                         module_title
# Excel Базовый                  Визуализация данных Excel                                    73.0
#                               Основной функционал Excel                                    179.0
#                               Основной функционал Excel (продолжение)                      376.0
#                               Сводные таблицы Excel                                        483.0
#                               Формулы и функции Excel. Более сложные формулы               813.0
#                               Формулы и функции Excel. Введение                            222.0
#                               Формулы и функции Excel. Продолжаем работать с ...           141.0
#                               Формулы и функции Excel. Работа с ошибками, про...            30.0
#                               Экзаменационная работа                                      1187.0
# Java-разработчик              Вводный модуль                                               106.0
#                               Веб-приложения: формы, заголовки и сессии                      5.0
#                               Внешний вид GUI и рисование                                    5.0
#                               Итоговая тема                                                  4.0
#                               Массивы и коллекции                                            5.0
#                               Многопоточность                                                6.0
#                               Наследование и полиморфизм                                     7.0
#                               Объекты и классы                                               7.0
#                               Оптимизация кода и приложений                                  5.0
#                               Основы построения GUI                                          7.0
#                               Основы построения веб-приложений                               4.0
#                               Работа с базами данных                                         5.0
#                               Работа с файлами и сетью                                       5.0
#                               Синтаксис языка                                                7.0
#                               Тестирование и отладка                                         4.0
#                               Числа, строки и даты                                          10.0
# Java-разработчик c нуля       Вводный модуль                                                76.0
#                               Исключения, отладка, тестирование и логгирование            4741.0
#                               Массивы и коллекции                                          210.0
#                               Наследование и полиморфизм                                   201.0
#                               Объекты и классы                                               3.0
# ...                                                                                          ...
# Интернет-маркетолог от Ingate Веб-аналитика: максимум информации об эффективн...             0.0
#                               Исследование целевой аудитории: портретирование...             0.0
#                               Контекстная реклама в Yandex Direct и Google Ad...             0.0
#                               Контент-маркетинг: стратегия коммуникации, кана...             0.0
#                               Маркетплейсы                                                   0.0
#                               Медиапланирование: разработка комплексной страт...             0.0
#                               Медийная реклама и RTB: охват или целевые польз...             0.0
#                               Партнерский CPA-маркетинг                                      0.0
#                               Построение маркетинговой структуры и работа с к...             0.0
#                               Таргетированная реклама в социальных сетях                     0.0
#                               Управление репутацией (SERM)                                   0.0
#                               Финальное тестирование                                       452.0
#                               Юзабилити: разработка эффективного сайта                       0.0
#                               Юридическая сторона рекламы                                    0.0
# Руководитель digital-проектов Scrum. Передовая методология управления digital...             0.0
#                               Scrum: передовая методология управления совреме...             0.0
#                               Аналитика. Базовые навыки                                      0.0
#                               Интеграционные проекты.                                        0.0
#                               Как пасти котов: правильное делегирование в IT                 0.0
#                               Контроль. Риски. Поощрения. Наказания. Обратная...             0.0
#                               Основы технической грамотности                                 0.0
#                               Оценка и декомпозиция digital-проектов                         0.0
#                               Переговорные навыки. Провокации. Работа с возра...             0.0
#                               Переговорные навыки. Часть 1. Цикл продаж                      0.0
#                               Релиз-менеджмент: готовим проекты к запуску                    0.0
#                               Решение факапов. Lean/TOC. Обзор.                              0.0
#                               Требовательность digital-продюсера                             0.0
#                               Управление временем                                            0.0
#                               Управление дизайнерами. Разработка дизайна по s...             0.0
#                               Экологичный путь менеджера                                     0.0
#
#                                                                                            \
#                                                                                       max
# title                         module_title
# Excel Базовый                  Визуализация данных Excel                          86399.0
#                               Основной функционал Excel                           86399.0
#                               Основной функционал Excel (продолжение)             86399.0
#                               Сводные таблицы Excel                               86399.0
#                               Формулы и функции Excel. Более сложные формулы      86399.0
#                               Формулы и функции Excel. Введение                   86399.0
#                               Формулы и функции Excel. Продолжаем работать с ...  86399.0
#                               Формулы и функции Excel. Работа с ошибками, про...  86399.0
#                               Экзаменационная работа                              84754.0
# Java-разработчик              Вводный модуль                                      86399.0
#                               Веб-приложения: формы, заголовки и сессии           86399.0
#                               Внешний вид GUI и рисование                         86399.0
#                               Итоговая тема                                       74617.0
#                               Массивы и коллекции                                 86399.0
#                               Многопоточность                                     86399.0
#                               Наследование и полиморфизм                          86399.0
#                               Объекты и классы                                    86399.0
#                               Оптимизация кода и приложений                       86399.0
#                               Основы построения GUI                               86399.0
#                               Основы построения веб-приложений                    86399.0
#                               Работа с базами данных                              86399.0
#                               Работа с файлами и сетью                            86399.0
#                               Синтаксис языка                                     86399.0
#                               Тестирование и отладка                              86399.0
#                               Числа, строки и даты                                86399.0
# Java-разработчик c нуля       Вводный модуль                                      86044.0
#                               Исключения, отладка, тестирование и логгирование    85901.0
#                               Массивы и коллекции                                 85111.0
#                               Наследование и полиморфизм                          85793.0
#                               Объекты и классы                                    86012.0
# ...                                                                                   ...
# Интернет-маркетолог от Ingate Веб-аналитика: максимум информации об эффективн...  86399.0
#                               Исследование целевой аудитории: портретирование...  86399.0
#                               Контекстная реклама в Yandex Direct и Google Ad...  86399.0
#                               Контент-маркетинг: стратегия коммуникации, кана...  86399.0
#                               Маркетплейсы                                        86399.0
#                               Медиапланирование: разработка комплексной страт...  86399.0
#                               Медийная реклама и RTB: охват или целевые польз...  86399.0
#                               Партнерский CPA-маркетинг                           86399.0
#                               Построение маркетинговой структуры и работа с к...  86399.0
#                               Таргетированная реклама в социальных сетях          86399.0
#                               Управление репутацией (SERM)                        86399.0
#                               Финальное тестирование                              85281.0
#                               Юзабилити: разработка эффективного сайта            86399.0
#                               Юридическая сторона рекламы                         86399.0
# Руководитель digital-проектов Scrum. Передовая методология управления digital...  86399.0
#                               Scrum: передовая методология управления совреме...  86399.0
#                               Аналитика. Базовые навыки                           86399.0
#                               Интеграционные проекты.                             86399.0
#                               Как пасти котов: правильное делегирование в IT      86399.0
#                               Контроль. Риски. Поощрения. Наказания. Обратная...  86399.0
#                               Основы технической грамотности                      86399.0
#                               Оценка и декомпозиция digital-проектов              86399.0
#                               Переговорные навыки. Провокации. Работа с возра...  86399.0
#                               Переговорные навыки. Часть 1. Цикл продаж           86399.0
#                               Релиз-менеджмент: готовим проекты к запуску         86399.0
#                               Решение факапов. Lean/TOC. Обзор.                   86399.0
#                               Требовательность digital-продюсера                  86399.0
#                               Управление временем                                 86399.0
#                               Управление дизайнерами. Разработка дизайна по s...  86399.0
#                               Экологичный путь менеджера                          86399.0
#
#                                                                                                 \
#                                                                                           mean
# title                         module_title
# Excel Базовый                  Визуализация данных Excel                          49721.115000
#                               Основной функционал Excel                           46057.978166
#                               Основной функционал Excel (продолжение)             47296.694581
#                               Сводные таблицы Excel                               46822.053763
#                               Формулы и функции Excel. Более сложные формулы      46700.544444
#                               Формулы и функции Excel. Введение                   48661.961240
#                               Формулы и функции Excel. Продолжаем работать с ...  45592.330033
#                               Формулы и функции Excel. Работа с ошибками, про...  47516.057851
#                               Экзаменационная работа                              43746.263736
# Java-разработчик              Вводный модуль                                      44254.351687
#                               Веб-приложения: формы, заголовки и сессии           51703.000000
#                               Внешний вид GUI и рисование                         40842.270270
#                               Итоговая тема                                       29701.285714
#                               Массивы и коллекции                                 47553.063584
#                               Многопоточность                                     42413.580645
#                               Наследование и полиморфизм                          42724.250000
#                               Объекты и классы                                    44940.394558
#                               Оптимизация кода и приложений                       47850.192308
#                               Основы построения GUI                               46359.320755
#                               Основы построения веб-приложений                    39899.260870
#                               Работа с базами данных                              51348.274510
#                               Работа с файлами и сетью                            49487.560606
#                               Синтаксис языка                                     42189.409836
#                               Тестирование и отладка                              43154.915493
#                               Числа, строки и даты                                44437.137931
# Java-разработчик c нуля       Вводный модуль                                      45389.024735
#                               Исключения, отладка, тестирование и логгирование    45156.142857
#                               Массивы и коллекции                                 41174.495050
#                               Наследование и полиморфизм                          44447.153846
#                               Объекты и классы                                    45189.806667
# ...                                                                                        ...
# Интернет-маркетолог от Ingate Веб-аналитика: максимум информации об эффективн...  55458.141304
#                               Исследование целевой аудитории: портретирование...  46296.057297
#                               Контекстная реклама в Yandex Direct и Google Ad...  41883.683099
#                               Контент-маркетинг: стратегия коммуникации, кана...  48469.764706
#                               Маркетплейсы                                        42848.370370
#                               Медиапланирование: разработка комплексной страт...  52189.491525
#                               Медийная реклама и RTB: охват или целевые польз...  44674.217295
#                               Партнерский CPA-маркетинг                           47030.762195
#                               Построение маркетинговой структуры и работа с к...  58387.631579
#                               Таргетированная реклама в социальных сетях          50465.640394
#                               Управление репутацией (SERM)                        46321.049911
#                               Финальное тестирование                              35951.357143
#                               Юзабилити: разработка эффективного сайта            48290.641304
#                               Юридическая сторона рекламы                         57360.016393
# Руководитель digital-проектов Scrum. Передовая методология управления digital...  53231.316327
#                               Scrum: передовая методология управления совреме...  50474.537037
#                               Аналитика. Базовые навыки                           52394.633929
#                               Интеграционные проекты.                             54824.492754
#                               Как пасти котов: правильное делегирование в IT      54788.055814
#                               Контроль. Риски. Поощрения. Наказания. Обратная...  59709.655172
#                               Основы технической грамотности                      55394.796875
#                               Оценка и декомпозиция digital-проектов              51781.888060
#                               Переговорные навыки. Провокации. Работа с возра...  51977.279221
#                               Переговорные навыки. Часть 1. Цикл продаж           52504.400000
#                               Релиз-менеджмент: готовим проекты к запуску         50621.445333
#                               Решение факапов. Lean/TOC. Обзор.                   52804.556818
#                               Требовательность digital-продюсера                  51471.608696
#                               Управление временем                                 52387.240310
#                               Управление дизайнерами. Разработка дизайна по s...  57912.234375
#                               Экологичный путь менеджера                          53368.912500
#
#
#                                                                                    median
# title                         module_title
# Excel Базовый                  Визуализация данных Excel                          53363.0
#                               Основной функционал Excel                           49380.5
#                               Основной функционал Excel (продолжение)             51148.0
#                               Сводные таблицы Excel                               50308.0
#                               Формулы и функции Excel. Более сложные формулы      47514.5
#                               Формулы и функции Excel. Введение                   52462.0
#                               Формулы и функции Excel. Продолжаем работать с ...  46659.0
#                               Формулы и функции Excel. Работа с ошибками, про...  51083.5
#                               Экзаменационная работа                              47990.0
# Java-разработчик              Вводный модуль                                      46220.0
#                               Веб-приложения: формы, заголовки и сессии           63963.0
#                               Внешний вид GUI и рисование                         40590.0
#                               Итоговая тема                                       26248.0
#                               Массивы и коллекции                                 52865.0
#                               Многопоточность                                     42409.0
#                               Наследование и полиморфизм                          43510.5
#                               Объекты и классы                                    43716.5
#                               Оптимизация кода и приложений                       52233.5
#                               Основы построения GUI                               48561.5
#                               Основы построения веб-приложений                    30234.0
#                               Работа с базами данных                              56632.0
#                               Работа с файлами и сетью                            56357.5
#                               Синтаксис языка                                     43501.0
#                               Тестирование и отладка                              44910.5
#                               Числа, строки и даты                                45019.5
# Java-разработчик c нуля       Вводный модуль                                      47222.0
#                               Исключения, отладка, тестирование и логгирование    50415.0
#                               Массивы и коллекции                                 42263.0
#                               Наследование и полиморфизм                          49718.0
#                               Объекты и классы                                    48441.0
# ...                                                                                   ...
# Интернет-маркетолог от Ingate Веб-аналитика: максимум информации об эффективн...  65571.5
#                               Исследование целевой аудитории: портретирование...  49016.0
#                               Контекстная реклама в Yandex Direct и Google Ad...  33831.5
#                               Контент-маркетинг: стратегия коммуникации, кана...  48297.0
#                               Маркетплейсы                                        32342.0
#                               Медиапланирование: разработка комплексной страт...  54587.0
#                               Медийная реклама и RTB: охват или целевые польз...  44916.0
#                               Партнерский CPA-маркетинг                           50534.0
#                               Построение маркетинговой структуры и работа с к...  68168.5
#                               Таргетированная реклама в социальных сетях          59108.0
#                               Управление репутацией (SERM)                        51541.0
#                               Финальное тестирование                              30715.5
#                               Юзабилити: разработка эффективного сайта            50809.5
#                               Юридическая сторона рекламы                         63461.0
# Руководитель digital-проектов Scrum. Передовая методология управления digital...  61121.0
#                               Scrum: передовая методология управления совреме...  56308.0
#                               Аналитика. Базовые навыки                           57690.0
#                               Интеграционные проекты.                             58966.0
#                               Как пасти котов: правильное делегирование в IT      60708.0
#                               Контроль. Риски. Поощрения. Наказания. Обратная...  64030.5
#                               Основы технической грамотности                      65142.0
#                               Оценка и декомпозиция digital-проектов              56403.0
#                               Переговорные навыки. Провокации. Работа с возра...  61664.0
#                               Переговорные навыки. Часть 1. Цикл продаж           58571.5
#                               Релиз-менеджмент: готовим проекты к запуску         56472.0
#                               Решение факапов. Lean/TOC. Обзор.                   56144.5
#                               Требовательность digital-продюсера                  58383.0
#                               Управление временем                                 57693.0
#                               Управление дизайнерами. Разработка дизайна по s...  65712.0
#                               Экологичный путь менеджера                          56309.0
#
# [191 rows x 4 columns]

# %% [markdown]
# 2. **(m)** На основании первого пункта построить line-graph с медианным временем прохождения каждого модуля для каждого курса. 15 графиков. Графики должны иметь заголовки

# %%
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters

# %matplotlib inline

# Произведу подсчет курсов
df_gr = df_result.loc[:, ['title', 'module_title', 'difference_date']].groupby(
    ['title', 'module_title']).median().reset_index().sort_values(by = ['title','difference_date'])

# получаем данные по графику
df_course_id = df_gr.loc[:, ['title', 'difference_date']]
df_gr.index = df_gr.title

for i in df_course_id.groupby('title').count().reset_index().values:
    
    register_matplotlib_converters()
    fig, subplot = plt.subplots()
    
    x = list(str(j) for j in df_gr.loc[i[0], 'module_title'].values)
    y = list(str(j) for j in df_gr.loc[i[0], 'difference_date'].values)

    # график функции
    subplot.plot(x, y)

    # подписываем график
    subplot.set_title(str(i[0]))
    
    # устанавливаем название для оси  OX
    subplot.set_ylabel('медианное время прохождения каждого модуля для каждого курса')

    # подписи для оси Ох
    x_labels = [str(i) for i in x]

    # добавляем подписи к осям
    plt.xticks(x, rotation='vertical', labels=x_labels)

    plt.show()

# %% [markdown]
# 3. **(p)**  Чтобы выявить сезонность, посчитать медианное время выполнения домашней работы по месяцам (12 месяцев, январь-декабрь) для каждого курса.

# %%
# получу месяцы из колонки "start_date" и посчитаю медианное время выполнения домашней работы по 
# месяцам (12 месяцев, январь-декабрь) для каждого курса.
df_median = df.loc[:, ['title', 'start_date', 'finish_date']]

# %%
df_median['month'] = df_median.loc[:, 'start_date'].apply(lambda x: x.month)

# %%
df_median['difference_date'] = df_median.loc[:, 'finish_date'] - df_median.loc[:, 'start_date']

# %%
# для удобного расчета переведу колонку 'difference_date' в секунды
df_median['difference_date'] = df_median.loc[:, 'difference_date'].apply(days_seconds)

# %%
df_mg = df_median.loc[:, ['title', 'month', 'difference_date']].groupby(['title', 'month']).agg('median')

# %%
df_mg.sort_values(by = ['title', 'difference_date'], ascending=False)
# Out:
#                                      difference_date
# title                         month
# Руководитель digital-проектов 2              67616.5
#                               10             61978.0
#                               8              61515.0
#                               9              61065.0
#                               12             60849.0
#                               6              59688.0
#                               7              57441.0
#                               1              56479.0
#                               5              55747.0
#                               3              55514.5
#                               11             55197.5
#                               4              52929.0
# Интернет-маркетолог от Ingate 7              58120.0
#                               2              53943.5
#                               12             51769.5
#                               11             51196.5
#                               6              50831.0
#                               3              49894.5
#                               5              49308.0
#                               4              49190.0
#                               8              49028.0
#                               9              48297.0
#                               1              44111.0
#                               10             35214.0
# Веб-разработчик               2              72690.0
#                               12             68430.0
#                               3              63771.0
#                               11             54975.0
#                               1              50447.0
#                               4              45533.0
# ...                                              ...
# JavaScript с нуля             4              38988.0
# Java-разработчик c нуля       3              51971.0
#                               4              49155.0
#                               5              48084.0
#                               7              44455.0
#                               6              44418.0
# Java-разработчик              10             63037.0
#                               12             51242.0
#                               1              50367.0
#                               5              48445.0
#                               11             47341.5
#                               2              46678.0
#                               9              45174.0
#                               4              42330.0
#                               3              41136.0
#                               7              38752.0
#                               8              28856.0
#                               6              28297.0
# Excel Базовый                 6              54610.0
#                               8              54416.0
#                               2              53696.0
#                               5              53234.5
#                               4              52799.5
#                               7              52644.0
#                               12             51348.0
#                               9              49096.0
#                               1              46235.0
#                               10             45726.0
#                               3              44309.0
#                               11             40480.0
#
# [171 rows x 1 columns]

# %% [markdown]
# 4. **(m)** На основании третьего пункта построить line-graph, на который будут нанесены линии для каждого курса с медианным временем выполнения домашней работы по месяцам. 15 линий на графике. График должен иметь заголовок. Ось, отражающая время прохождения, должна быть подписана. Линия для каждого курса должна иметь свой цвет (нужна легенда). Рамок у графика быть не должно  ⭐

# %%
import matplotlib.pyplot as plt

# %%
df_graf = df_mg.reset_index()
df_course = df_graf.loc[:, 'title'].reset_index().groupby('title').count().index
df_graf.index = df_graf.title

for i in df_course:
    plt.plot(df_graf.loc[i, 'month'].values, df_graf.loc[i, 'difference_date'].values, label = i)

plt.xlabel('месяцы', fontsize=15, color='blue')
plt.ylabel('медианное время выплнения', fontsize=15, color='blue')
plt.title('График', fontsize=17)
plt.legend(loc=1)
plt.rcParams["figure.figsize"] = (20, 10)

subplot = plt.subplot()
# удалю рамку
subplot.set_frame_on(False)

plt.show()
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:26: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %% [markdown]
# 5. На основании рассчитанных значений сделайте аналитический вывод (должен быть полным и покрывать все полученные выше метрики)

# %% [markdown]
# **Вывод** На основании полученных данных можно сказать что разные модули в курсах имеют разное время прохождения, какие то больше какие то меньше, но это и логично, в каждом курсе данные по знаниям разные где то больше где то меньше. По поводу сезонности тоже явного признака нет, так что твердо утверждать что у такого то курса в таких то месяцах будет обязательный прирост я бы не спешил.

# %% [markdown]
# ## 4. Расчет конверсии
#
# 1. **(p)** Посчитать конверсию перехода студентов из одного модуля в другой на каждом курсе. Формула: отношение количества студентов, приступивших к выполнению домашнего задания в этом модуле (если дз в модуле несколько, то считать по первому дз в модуле), к количеству студентов, сдавших задание в предыдущем модуле (если дз в модуле несколько, то считать по последнему дз в модуле).
# 2. **(m)** Постройте bar-chart, отражающий конверсию перехода студентов из одного модуля в другой на каждом курсе. График должен иметь заголовок. Ticks нужно развернуть так, чтобы они были читаемы
# 3. **(m)** Постройте горизонтальный (столбцы должны располагаться горизонтально) bar-chart, отражающий конверсию перехода студентов из одного модуля в другой на каждом курсе. 15 графиков. Графики должны иметь заголовки. Ticks должны содержать номер и название модуля. Цвет столбцов графиков должен содержать информацию о сфере, к которой относится курс (нужна легенда). Прозрачность должна стоять на отметке 0.1. На графики должна быть нанесена линия медианы конверсии для каждого курса. У медианы должен быть свой цвет. Рамок у графиков быть не должно ⭐
# 4. На основании рассчитанных значений сделайте аналитический вывод (должен быть полным и покрывать все полученные выше метрики)

# %%
# Подготовка данных
import pandas as pd

df_courses = pd.read_csv("./Data/courses.csv", encoding="UTF-8")
df_course_contents = pd.read_csv("./Data/course_contents.csv", encoding="UTF-8")
df_progresses = pd.read_csv("./Data/progresses.csv", encoding="UTF-8")
df_progress_phases = pd.read_csv("./Data/progress_phases.csv", encoding="UTF-8")

result = pd.merge(df_progress_phases, df_progresses, how='left', left_on='progress_id', right_on='id')
result2 = pd.merge(result, df_courses, how='left', left_on=['course_id'], right_on=['id'])
main = pd.merge(result2, df_course_contents, how='left', 
                   left_on=['course_id', 'module_number', 'lesson_number'], 
                   right_on=['course_id', 'module_number', 'lesson_number'])
del main['id_y']
del main['id_x']
del main['Unnamed: 0']
main.head()
# Out:
#                         progress_id  module_number  lesson_number status  \
# 0  a387ab916f402cb3fbfffd29f68fd0ce              2              4   done
# 1  a387ab916f402cb3fbfffd29f68fd0ce              1              1   done
# 2  a387ab916f402cb3fbfffd29f68fd0ce              2              2   done
# 3  a387ab916f402cb3fbfffd29f68fd0ce              1              4   done
# 4  a387ab916f402cb3fbfffd29f68fd0ce              1              6   done
#
#                       start_date                    finish_date  \
# 0  2018-06-23 08:28:50.681065+00  2018-06-23 08:28:52.439542+00
# 1  2018-06-20 14:25:21.783762+00  2018-06-20 15:45:07.717209+00
# 2  2018-06-23 08:18:09.653771+00  2018-06-23 08:18:12.784616+00
# 3   2018-06-20 16:00:06.36178+00  2018-06-21 19:09:30.845034+00
# 4  2018-06-21 19:10:36.957891+00  2018-06-28 15:59:25.320418+00
#
#                          student_id                         course_id  \
# 0  768c2987a744c51ce64a5993a2a94eaf  c9fcb746d51e41bc5a217002d081454b
# 1  768c2987a744c51ce64a5993a2a94eaf  c9fcb746d51e41bc5a217002d081454b
# 2  768c2987a744c51ce64a5993a2a94eaf  c9fcb746d51e41bc5a217002d081454b
# 3  768c2987a744c51ce64a5993a2a94eaf  c9fcb746d51e41bc5a217002d081454b
# 4  768c2987a744c51ce64a5993a2a94eaf  c9fcb746d51e41bc5a217002d081454b
#
#                 title   field                             module_title  \
# 0  Веб-дизайн PRO 2.0  Design                    Концептуальный дизайн
# 1  Веб-дизайн PRO 2.0  Design  Специализация и личное позиционирование
# 2  Веб-дизайн PRO 2.0  Design                    Концептуальный дизайн
# 3  Веб-дизайн PRO 2.0  Design  Специализация и личное позиционирование
# 4  Веб-дизайн PRO 2.0  Design  Специализация и личное позиционирование
#
#                       lesson_title                          lesson_token  \
# 0                Практика — мокапы  7df8adef-1259-4b72-9bf2-353c73389d06
# 1                      Интро курса  df1a1f20-cdf7-443d-b25b-0a4b990b84d9
# 2  Что такое концептуальный дизайн  f23b1890-9365-406f-816b-04864cefe58f
# 3          Личное позиционирование  9dd50916-4aa6-4a73-b86c-56a1bd7753c8
# 4                  Домашняя работа  43e1fbdd-1ee9-4ed5-a577-4dadd80c02b3
#
#    is_video  is_homework
# 0      True        False
# 1      True        False
# 2      True        False
# 3      True        False
# 4     False         True

# %% [markdown]
# 1. **(p)** Посчитать конверсию перехода студентов из одного модуля в другой на каждом курсе. Формула: отношение количества студентов, приступивших к выполнению домашнего задания в этом модуле (если дз в модуле несколько, то считать по первому дз в модуле), к количеству студентов, сдавших задание в предыдущем модуле (если дз в модуле несколько, то считать по последнему дз в модуле).

# %%
# Выберем нужные колонки для работы
df = main.loc[:, ['title', 'module_title', 'module_number', 'is_homework', 'student_id', 'start_date', 'finish_date']]

# возьмем только домашние работы
df = df[df['is_homework'] == True]

# %%
# преобразую к типу дата колонки 'start_date' и 'finish_date'
df['start_date'] = pd.to_datetime(df['start_date'])
df['finish_date'] = pd.to_datetime(df['finish_date'])

# %%
# найду количества студентов, приступивших к выполнению домашнего задания в модуле
df_start = df.loc[:, ['title', 'module_number', 'start_date', 'student_id']]
Series_start_homework = df_start.groupby(['title', 'module_number', 'student_id'])['start_date'].agg('min')
df_start_homework = Series_start_homework.groupby(['title', 'module_number']).count()

# %%
df_sh = df_start_homework.reset_index()
df_sh.rename(columns={'start_date': 'start_count_students'}, inplace=True)
df_sh
# Out:
#                              title  module_number  start_count_students
# 0                    Excel Базовый              1                   518
# 1                    Excel Базовый              2                   434
# 2                    Excel Базовый              3                   398
# 3                    Excel Базовый              4                   345
# 4                    Excel Базовый              5                   298
# 5                    Excel Базовый              6                   263
# 6                    Excel Базовый              7                   238
# 7                    Excel Базовый              8                   202
# 8                    Excel Базовый              9                   191
# 9                 Java-разработчик              1                   627
# 10                Java-разработчик              2                   521
# 11                Java-разработчик              3                   374
# 12                Java-разработчик              4                   283
# 13                Java-разработчик              5                   216
# 14                Java-разработчик              6                   175
# 15                Java-разработчик              7                   158
# 16                Java-разработчик              8                   136
# 17                Java-разработчик              9                   112
# 18                Java-разработчик             10                    75
# 19                Java-разработчик             11                    69
# 20                Java-разработчик             12                    52
# 21                Java-разработчик             13                    33
# 22                Java-разработчик             14                    25
# 23                Java-разработчик             15                    24
# 24                Java-разработчик             17                    21
# 25         Java-разработчик c нуля              1                   418
# 26         Java-разработчик c нуля              2                   279
# 27         Java-разработчик c нуля              3                   211
# 28         Java-разработчик c нуля              4                   162
# 29         Java-разработчик c нуля              5                   106
# ..                             ...            ...                   ...
# 161  Интернет-маркетолог от Ingate              5                   535
# 162  Интернет-маркетолог от Ingate              6                   419
# 163  Интернет-маркетолог от Ingate              7                   326
# 164  Интернет-маркетолог от Ingate              8                   291
# 165  Интернет-маркетолог от Ingate              9                   238
# 166  Интернет-маркетолог от Ingate             10                   201
# 167  Интернет-маркетолог от Ingate             11                   189
# 168  Интернет-маркетолог от Ingate             12                   162
# 169  Интернет-маркетолог от Ingate             13                   118
# 170  Интернет-маркетолог от Ingate             14                   102
# 171  Интернет-маркетолог от Ingate             15                    89
# 172  Интернет-маркетолог от Ingate             16                    77
# 173  Интернет-маркетолог от Ingate             17                    69
# 174  Интернет-маркетолог от Ingate             18                    28
# 175  Руководитель digital-проектов              1                   598
# 176  Руководитель digital-проектов              2                   537
# 177  Руководитель digital-проектов              3                   402
# 178  Руководитель digital-проектов              4                   335
# 179  Руководитель digital-проектов              5                   235
# 180  Руководитель digital-проектов              6                   214
# 181  Руководитель digital-проектов              7                   197
# 182  Руководитель digital-проектов              8                   158
# 183  Руководитель digital-проектов              9                   136
# 184  Руководитель digital-проектов             10                   125
# 185  Руководитель digital-проектов             11                   107
# 186  Руководитель digital-проектов             12                    95
# 187  Руководитель digital-проектов             13                    87
# 188  Руководитель digital-проектов             14                    71
# 189  Руководитель digital-проектов             15                    66
# 190  Руководитель digital-проектов             16                    64
#
# [191 rows x 3 columns]

# %%
# найду количество студентов, сдавших задание в предыдущем модуле (если дз в модуле несколько, то считать по последнему 
df_finish = df.loc[:, ['title', 'module_number', 'finish_date', 'student_id']]
Series_finish_homework = df_finish.groupby(['title', 'module_number', 'student_id'])['finish_date'].agg('max')
df_finish_homework = Series_finish_homework.groupby(['title', 'module_number']).count()

# %%
df_fh = df_finish_homework.reset_index()
df_fh.rename(columns={'finish_date': 'finish_count_students'}, inplace=True)
df_fh
# Out:
#                              title  module_number  finish_count_students
# 0                    Excel Базовый              1                    458
# 1                    Excel Базовый              2                    406
# 2                    Excel Базовый              3                    387
# 3                    Excel Базовый              4                    303
# 4                    Excel Базовый              5                    270
# 5                    Excel Базовый              6                    242
# 6                    Excel Базовый              7                    200
# 7                    Excel Базовый              8                    186
# 8                    Excel Базовый              9                     91
# 9                 Java-разработчик              1                    563
# 10                Java-разработчик              2                    427
# 11                Java-разработчик              3                    294
# 12                Java-разработчик              4                    232
# 13                Java-разработчик              5                    173
# 14                Java-разработчик              6                    160
# 15                Java-разработчик              7                    142
# 16                Java-разработчик              8                    106
# 17                Java-разработчик              9                     74
# 18                Java-разработчик             10                     66
# 19                Java-разработчик             11                     51
# 20                Java-разработчик             12                     31
# 21                Java-разработчик             13                     26
# 22                Java-разработчик             14                     23
# 23                Java-разработчик             15                     19
# 24                Java-разработчик             17                      7
# 25         Java-разработчик c нуля              1                    283
# 26         Java-разработчик c нуля              2                    221
# 27         Java-разработчик c нуля              3                    150
# 28         Java-разработчик c нуля              4                    151
# 29         Java-разработчик c нуля              5                    101
# ..                             ...            ...                    ...
# 161  Интернет-маркетолог от Ingate              5                    451
# 162  Интернет-маркетолог от Ingate              6                    284
# 163  Интернет-маркетолог от Ingate              7                    297
# 164  Интернет-маркетолог от Ingate              8                    238
# 165  Интернет-маркетолог от Ingate              9                    203
# 166  Интернет-маркетолог от Ingate             10                    187
# 167  Интернет-маркетолог от Ingate             11                    164
# 168  Интернет-маркетолог от Ingate             12                    118
# 169  Интернет-маркетолог от Ingate             13                     92
# 170  Интернет-маркетолог от Ingate             14                     92
# 171  Интернет-маркетолог от Ingate             15                     76
# 172  Интернет-маркетолог от Ingate             16                     70
# 173  Интернет-маркетолог от Ingate             17                     61
# 174  Интернет-маркетолог от Ingate             18                     14
# 175  Руководитель digital-проектов              1                    560
# 176  Руководитель digital-проектов              2                    375
# 177  Руководитель digital-проектов              3                    345
# 178  Руководитель digital-проектов              4                    224
# 179  Руководитель digital-проектов              5                    215
# 180  Руководитель digital-проектов              6                    200
# 181  Руководитель digital-проектов              7                    154
# 182  Руководитель digital-проектов              8                    134
# 183  Руководитель digital-проектов              9                    129
# 184  Руководитель digital-проектов             10                    108
# 185  Руководитель digital-проектов             11                     98
# 186  Руководитель digital-проектов             12                     88
# 187  Руководитель digital-проектов             13                     69
# 188  Руководитель digital-проектов             14                     64
# 189  Руководитель digital-проектов             15                     64
# 190  Руководитель digital-проектов             16                     58
#
# [191 rows x 3 columns]

# %%
# Для нахождения конверсии мне нужно что бы в таблице модуль с количеством приступивших был в одной строке с модулем с 
# количеством окончивших прибавим к номеру модуля окончивших единицу
df_fh['module_number'] = df_fh['module_number'] + 1

# %%
# соединим датафреймы по колонкам 'title', 'module_number'
df_convers = pd.merge(df_sh, df_fh, left_on=['title', 'module_number'], right_on=['title', 'module_number'])

# %%
# добавлю новую колонку и расчитаю конверсию
df_convers['conversion'] = df_convers['start_count_students'] / df_convers['finish_count_students']

# %%
# в колонке "conversion" мы видим расчитанную конверсию
df_convers.head(10)
# Out:
#               title  module_number  start_count_students  \
# 0     Excel Базовый              2                   434
# 1     Excel Базовый              3                   398
# 2     Excel Базовый              4                   345
# 3     Excel Базовый              5                   298
# 4     Excel Базовый              6                   263
# 5     Excel Базовый              7                   238
# 6     Excel Базовый              8                   202
# 7     Excel Базовый              9                   191
# 8  Java-разработчик              2                   521
# 9  Java-разработчик              3                   374
#
#    finish_count_students  conversion
# 0                    458    0.947598
# 1                    406    0.980296
# 2                    387    0.891473
# 3                    303    0.983498
# 4                    270    0.974074
# 5                    242    0.983471
# 6                    200    1.010000
# 7                    186    1.026882
# 8                    563    0.925400
# 9                    427    0.875878

# %% [markdown]
# 2. **(m)** Постройте bar-chart, отражающий конверсию перехода студентов из одного модуля в другой на каждом курсе. График должен иметь заголовок. Ticks нужно развернуть так, чтобы они были читаемы

# %%
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters

# %matplotlib inline

register_matplotlib_converters()
fig, subplot = plt.subplots()

# получаем данные по графику
# найду медианное значение конверсии по модулям по каждому курсу
df_title_conversion = df_convers.loc[:, ['title', 'conversion']].groupby(['title']).median()
conversion = df_title_conversion.loc[:, 'conversion'].values
x_axis = df_title_conversion.index.values

# график функции
subplot.bar(x = x_axis, height = conversion)

# подписываем график
subplot.set_title("Конверсия по курсам")

# подписи для оси Ох
x_labels = [str(i) for i in x_axis]

# добавляем подписи к осям
plt.xticks(x_axis, rotation='vertical', labels=x_labels)

plt.show()

# %% [markdown]
# 4. На основании рассчитанных значений сделайте аналитический вывод (должен быть полным и покрывать все полученные выше метрики)

# %% [markdown]
# **Вывод** исходя из полученных данных можно сказать что в целом конверсия по курсам одинаковая, но в семье не без урода и тут у нас есть самый низкий , выбивающийся из всех курсов, показатель конверсии по курсу 'Java-разработчик c нуля'

# %% [markdown]
# ## 5. Метрика успеваемости
#
# &nbsp;&nbsp;&nbsp;&nbsp;*(необязательное задание)*
#
# Иногда студенты берут курсы, которые оказываются для них неподъемными. Это может быть как по причинам недостаточной изначальной подготовки, так и по причинам, связанным с низкой мотивацией студента. Для улучшения качества контента полезно выявить причину. На основании имеющихся данных придумайте метрику успеваемости студента. **Обоснуйте ее.** Выявите таких студентов на каждом курсе, чтобы предоставить продюсерам список проблемных студентов.

# %%
### YOUR CODE HERE ###
